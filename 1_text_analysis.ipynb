# %%
import pandas as pd
import spacy
import numpy as np
import re
import os
import pickle
from sklearn.metrics import precision_recall_fscore_support, accuracy_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import KFold
from sklearn.dummy import DummyClassifier
from sklearn.feature_selection import SelectKBest, chi2
from numpy import random
from scipy import sparse
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
random.randint(1, 79, 10)
# Out:
# array([48, 67, 55, 23,  8, 72, 44, 27, 16, 63])

# %%
nlp = spacy.load("en_core_web_sm", disable=['parser', 'ner'])

# %%
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Bingbo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
#stopwords = set("et al v. s.ct u.s. opinion dissent dissenting concur concurring alito breyer ginsburg gorsuch kagan kavanaugh kennedy o'Connor per curiam rehnquist roberts scalia sotomayor souter stevens thomas".split())
import nltk
nltk.download('stopwords')
stopwords_ = set(stopwords.words('english'))
spaces = re.compile('[\r\n\t\s]+')
numbers = re.compile('[0-9]')
                
def clean(text):
    return ' '.join([token.lemma_.lower() for token in text
            if token.lemma_.lower() not in stopwords_ 
            and not token.is_stop 
            and not token.is_punct
            and token.pos_ in {'NOUN', 'VERB', 'ADJ', 'ADV', 'PROPN', 'X'}
            and len(token.lemma_.lower()) > 1
           ])

def insights(X_sel, y, selector, N=10):
    classifier_sel = LogisticRegression(class_weight='balanced',
                                        solver='saga',
                                        penalty='elasticnet', 
                                        l1_ratio=0.5, 
                                        n_jobs=-1).fit(X_sel, y)
    # get the names of the features
    features = vectorizer.get_feature_names()
    num_feats = len(features)
    reduced_size = classifier_sel.coef_.shape[1]

    # get the indices of the selection
    top_scores = selector.scores_.argsort()[-num_feats:]

    # sort feature names
    best_indicator_terms = [features[i] for i in sorted(top_scores)] 

    # get class with highest weight for each feature
    top_class = [classifier_sel.classes_[c] for c in classifier_sel.coef_.argmax(axis=0)]

    # make DataFrame
    top_indicator_scores = pd.DataFrame(data={'feature': best_indicator_terms[:reduced_size], 
                                              'class': top_class[:reduced_size],
                                              'coefficient': classifier_sel.coef_.max(axis=0)})

    # sort in descending order
    top_indicator_scores.sort_values(['class', 'coefficient'], ascending=False, inplace=True)
    return top_indicator_scores.groupby('class').head(N)

def evaluate(X, y, selector):
    c_dumb, c_lr = {}, {}
    kf = KFold(n_splits=5)
    
    if not(selector is None):
        X_sel = selector.fit_transform(X, y)
    else:
        X_sel = X

    most_frequent = DummyClassifier(strategy='most_frequent')
    most_frequent.fit(X_sel, y)
    # get the performance on the development set
    dumb_predictions = most_frequent.predict(X_sel)
    print("DUMB predictor")
    print(classification_report(y, dumb_predictions))
    c_dumb['prec'], c_dumb['rec'], c_dumb['f1'], _ = precision_recall_fscore_support(y, dumb_predictions, average='macro')
    c_dumb['acc'] = accuracy_score(y, dumb_predictions)
    
    preds = cross_val_predict(LogisticRegression(class_weight='balanced'), X_sel, y, cv=5)
    print(classification_report(y, preds))
    c_lr['prec'], c_lr['rec'], c_lr['f1'], _ = precision_recall_fscore_support(y, preds, average='macro')
    c_lr['acc'] = accuracy_score(y, preds)

    return c_dumb, c_lr

def evaluate_split(X, y, selector):
    c_dumb = {}

    kf = KFold(n_splits=5)
    
    if not(selector is None):
        X_sel = selector.fit_transform(X, y)
    else:
        X_sel = X

    most_frequent = DummyClassifier(strategy='most_frequent')
    most_frequent.fit(X_sel, y)
    # get the performance on the development set
    dumb_predictions = most_frequent.predict(X_sel)
    print("DUMB predictor")
    print(classification_report(y, dumb_predictions))
    
    
    
    forest = RandomForestClassifier(random_state=1)
    multi_target_forest = MultiOutputClassifier(forest, n_jobs=-1)
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        y_preds = multi_target_forest.fit(X_train, y_train).predict(X_test)
        
        print(classification_report(y_test, preds))

    return X_sel
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Bingbo\AppData\Local\Temp\ipykernel_26188\2159803590.py:5: SyntaxWarning: invalid escape sequence '\s'
#   spaces = re.compile('[\r\n\t\s]+')
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Bingbo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Load Data

# %%
text_columns = ['description','title','publicationname']

taxonomy = "vigna"

if taxonomy=="vigna":
    target_fields = ['micro', 'theory', 'macro', 'labor', 'econom', 'industrial', 'international', 'finance', 'public',
          'healthurban', 'history', 'develop', 'lab', 'other']
elif taxonomy=='os':
    target_fields = ['OS_econom', 'OS_labor_health', 'OS_micro', 'OS_envir_agric',
       'OS_devel_intern_growth', 'OS_macro_finance', 'OS_IO', 'OS_public',
       'OS_history', 'OS_other']
elif taxonomy=="beneito":
    target_fields=['B_ldisc', 'B_wellbeing', 'B_demo',
       'B_general', 'B_labor', 'B_historyeco', 'B_health', 'B_education',
       'B_gamet', 'B_hhbehaviour', 'B_develop', 'B_business', 'B_wages',
       'B_naturalr', 'B_public', 'B_demandlab', 'B_trade', 'B_industrial',
       'B_intern', 'B_welfare', 'B_urbanregional', 'B_ecohistory',
       'B_lawecon', 'B_collectivedec', 'B_financial', 'B_macroconsum',
       'B_macropolicy', 'B_prod', 'B_inf', 'B_macromoney',
       'B_macroprices', 'B_math', 'B_other']



if os.path.exists("data/pub.pkl"):
    filehandler = open("data/pub.pkl", 'rb') 
    df = pickle.load(filehandler)
else:
    df = pd.read_stata("data\pub_all_Nov23 (2).dta")

    # select text column
    df['TEXT'] = df['description']
    df = df[df.TEXT != '']

    # clean text
    no_space = df.TEXT.apply(lambda x: re.sub(spaces, ' ', x)).apply(lambda x: re.sub(numbers, '0', x))
    clean_texts = []
    for text in nlp.pipe(no_space):
        clean_texts.append(clean(text)) 

    df['CLEAN_TEXT'] = clean_texts

    # save
    with open("data/pub.pkl", 'wb') as file:
        pickle.dump(df, file)
# Out:
# <>:28: SyntaxWarning: invalid escape sequence '\p'
# <>:28: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\Bingbo\AppData\Local\Temp\ipykernel_26188\237373761.py:28: SyntaxWarning: invalid escape sequence '\p'
#   df = pd.read_stata("data\pub_all_Nov23 (2).dta")

# %%
for c in df.columns:
    print('*',c,'*')
    print(df[c].iloc[1])
# Out:
# * auth_id *
# 11240938700.0
# * cognome *
# ABATEMARCO
# * initials *
# A
# * nome *
# Antonio
# * affiliation *
# UniversitÌåÊ di Salerno
# * documents *
# 12.0
# * affiliation_id *
# 60007061.0
# * city *
# Salerno
# * country *
# Italy
# * areas *
# ECON (11); SOCI (11); DECI (2)
# * areas2 *
# nan
# * dup2 *
# 0.0
# * merge3 *
# matched (3)
# * eid *
# 2-s2.0-85077148210
# * doi *
# 10.1007/s12232-019-00342-9
# * pii *
#
# * pubmed_id *
# nan
# * title *
# Equality of opportunity in health care: access and equal access revisited
# * subtype *
# ar
# * subtypedescription *
# Article
# * creator *
# Abatemarco A.
# * afid *
# 60017293;60007061
# * affilname *
# UniversitÌÊ degli Studi di Napoli Federico II;UniversitÌÊ degli Studi di Salerno
# * affiliation_city *
# Naples;Salerno
# * affiliation_country *
# Italy;Italy
# * author_count *
# 3.0
# * author_names *
# Abatemarco, Antonio;Beraldo, Sergio;Stroffolini, Francesca
# * author_ids *
# 11240938700;16551797700;7004595039
# * author_afids *
# 60007061;60017293;60017293
# * coverdate *
# 2020-03-01
# * coverdisplaydate *
# 1 March 2020
# * publicationname *
# International Review of Economics
# * issn *
# 18651704
# * source_id *
# 11500153504.0
# * eissn *
# 18634613
# * aggregationtype *
# Journal
# * issueidentifier *
# 1
# * article_number *
#
# * pagerange *
# 13-29
# * description *
# We offer a framework for identifying disparities in the distribution of healthcare opportunities. In line with the Rawlsian tradition of fair equality of opportunity, we argue that these have to be primarily defined in terms of access to a (bundle of) health services of appropriate quality. Our approach allows to disentangle the opportunities individuals enjoyassessed by jointly considering chances of access and disparities in access conditionsfrom the mere utilization of health services while preserving normative consistency with the principle of equal (access to) health care for those in equal need of health care. A simple exercise based on real data shows that the definition we provide can be easily applied to gather policy-relevant insights.
# * authkeywords *
# Access costs | Equality of opportunity | Health care
# * citedby_count *
# 4.0
# * openaccess *
# 0.0
# * fund_acr *
# UNITN
# * fund_no *
# undefined
# * fund_sponsor *
# UniversitÌÊ degli Studi Roma Tre
# * merge2 *
# matched (3)
# * counting *
# 9999.0
# * JEL *
# ['I14', 'I18']
# * url *
# https://link.springer.com/article/10.1007/s12232-019-00342-9
# * file *
# 10
# * fulleid *
#
# * auth_id3 *
#
# * ndup *
# nan
# * auth_id2 *
#
# * cognomenome *
# antonio abatemarco
# * Surname *
# ABATEMARCO
# * Name *
# Antonio
# * aux *
#  I14   I18
# * jel3_1 *
# I14
# * jel1_1 *
# I
# * jel2_1 *
# I1
# * jel3_2 *
# I18
# * jel1_2 *
# I
# * jel2_2 *
# I1
# * jel3_3 *
#
# * jel1_3 *
#
# * jel2_3 *
#
# * jel3_4 *
#
# * jel1_4 *
#
# * jel2_4 *
#
# * jel3_5 *
#
# * jel1_5 *
#
# * jel2_5 *
#
# * jel3_6 *
#
# * jel1_6 *
#
# * jel2_6 *
#
# * micro *
# 0.0
# * theory *
# 0.0
# * macro *
# 0.0
# * labor *
# 0.0
# * econom *
# 0.0
# * industrial *
# 0.0
# * international *
# 0.0
# * finance *
# 0.0
# * public *
# 0.0
# * healthurban *
# 1.0
# * history *
# 0.0
# * develop *
# 0.0
# * lab *
# 0.0
# * other *
# 0.0
# * OS_econom *
# 0.0
# * OS_labor_health *
# 1.0
# * OS_micro *
# 0.0
# * OS_envir_agric *
# 0.0
# * OS_devel_intern_growth *
# 0.0
# * OS_macro_finance *
# 0.0
# * OS_IO *
# 0.0
# * OS_public *
# 0.0
# * OS_history *
# 0.0
# * OS_other *
# 0.0
# * B_ldisc *
# 0.0
# * B_wellbeing *
# 0.0
# * B_demo *
# 0.0
# * B_general *
# 0.0
# * B_labor *
# 0.0
# * B_historyeco *
# 0.0
# * B_health *
# 1.0
# * B_education *
# 0.0
# * B_gamet *
# 0.0
# * B_hhbehaviour *
# 0.0
# * B_develop *
# 0.0
# * B_business *
# 0.0
# * B_wages *
# 0.0
# * B_naturalr *
# 0.0
# * B_public *
# 0.0
# * B_demandlab *
# 0.0
# * B_trade *
# 0.0
# * B_industrial *
# 0.0
# * B_intern *
# 0.0
# * B_welfare *
# 0.0
# * B_urbanregional *
# 0.0
# * B_ecohistory *
# 0.0
# * B_lawecon *
# 0.0
# * B_collectivedec *
# 0.0
# * B_financial *
# 0.0
# * B_macroconsum *
# 0.0
# * B_macropolicy *
# 0.0
# * B_prod *
# 0.0
# * B_inf *
# 0.0
# * B_macromoney *
# 0.0
# * B_macroprices *
# 0.0
# * B_math *
# 0.0
# * B_other *
# 0.0
# * fascia *
# Associato
# * sex *
# M
# * ateneo *
# SALERNO
# * facolt *
#
# * ssd *
# SECS-P/03
# * sc *
# 13/A3
# * strutturadiafferenza *
# Scienze Economiche e Statistiche
# * servizioprestatoinaltroateneo *
#
# * year *
# 2021.0
# * econ *
# 9.0
# * _merge *
# Matched (3)
# * prof *
# 1.0
# * dup *
# nan
# * n *
# nan
# * mwinner *
# nan
# * volume *
#
# * subtypeDescription *
#
# * coverDate *
#
# * yearpub *
# nan
# * keywords *
#
# * manually *
# nan
# * TEXT *
# We offer a framework for identifying disparities in the distribution of healthcare opportunities. In line with the Rawlsian tradition of fair equality of opportunity, we argue that these have to be primarily defined in terms of access to a (bundle of) health services of appropriate quality. Our approach allows to disentangle the opportunities individuals enjoyassessed by jointly considering chances of access and disparities in access conditionsfrom the mere utilization of health services while preserving normative consistency with the principle of equal (access to) health care for those in equal need of health care. A simple exercise based on real data shows that the definition we provide can be easily applied to gather policy-relevant insights.
# * CLEAN_TEXT *
# offer framework identifying disparitieso distribution healthcare opportunitieso line rawlsian tradition fair equality opportunity argue primarily defined terms access bundle health services appropriato quality approach allows disentangle opportunitieso individuals enjoyassessed jointly considering chances access disparitieso access conditionsfrom mere utilization health services preserving normative consistency principla equal access health care thosa equal need health caro simple exercisa based reale data shows definition provide easily applie ed gather policy relevant insights

# %% [markdown]
# ## Split data

# %%
train = df[df['JEL'] != "-"]
test = df[df['JEL'] == "-"]

#we do cross validation
#train, val = train_test_split(labeled_data, test_size=0.2, random_state=42)

print("Train Size:",len(train),len(train)/len(df)*100)
print("Test Size:",len(test),len(test)/len(df)*100)
#print("Val Size:",len(val),len(val)/len(df)*100)


y = sparse.csr_matrix(train[target_fields])
#y = train[target_fields]
# Out:
# Train Size: 9087 24.735953832752614
# Test Size: 27649 75.26404616724739

# %%
len(df)
# Out:
# 36736

# %% [markdown]
# # Classify data

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,3), min_df=0.01, max_df=0.5, sublinear_tf=True)
X_train = vectorizer.fit_transform(train['CLEAN_TEXT'])
X_test = vectorizer.transform(test['CLEAN_TEXT'])
#X_val = vectorizer.transform(val['CLEAN_TEXT'])
print(X_train.shape,X_test.shape)
# Out:
# (9042, 1469) (27488, 1469)

# %%
selector = SelectKBest(chi2, k=1000)
#selector = None

# %%
results = {}
results_dumb = {}
insight = {}

for t in target_fields:
    y_sel = train[t].astype(int)

    results_dumb[t], results[t] = evaluate(X_train, y_sel, selector)
    insight[t] = insights(X_train, y_sel, selector, 30)
# Out:
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9003
#            1       0.00      0.00      0.00        39
#
#     accuracy                           1.00      9042
#    macro avg       0.50      0.50      0.50      9042
# weighted avg       0.99      1.00      0.99      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9003
#            1       0.42      0.72      0.53        39
#
#     accuracy                           0.99      9042
#    macro avg       0.71      0.86      0.76      9042
# weighted avg       1.00      0.99      1.00      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8845
#            1       0.00      0.00      0.00       197
#
#     accuracy                           0.98      9042
#    macro avg       0.49      0.50      0.49      9042
# weighted avg       0.96      0.98      0.97      9042
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98      8845
#            1       0.34      0.77      0.47       197
#
#     accuracy                           0.96      9042
#    macro avg       0.67      0.87      0.72      9042
# weighted avg       0.98      0.96      0.97      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      8625
#            1       0.00      0.00      0.00       417
#
#     accuracy                           0.95      9042
#    macro avg       0.48      0.50      0.49      9042
# weighted avg       0.91      0.95      0.93      9042
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.97      8625
#            1       0.41      0.83      0.55       417
#
#     accuracy                           0.94      9042
#    macro avg       0.70      0.89      0.76      9042
# weighted avg       0.96      0.94      0.95      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8893
#            1       0.00      0.00      0.00       149
#
#     accuracy                           0.98      9042
#    macro avg       0.49      0.50      0.50      9042
# weighted avg       0.97      0.98      0.98      9042
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98      8893
#            1       0.33      0.73      0.45       149
#
#     accuracy                           0.97      9042
#    macro avg       0.66      0.85      0.72      9042
# weighted avg       0.98      0.97      0.98      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      8566
#            1       0.00      0.00      0.00       476
#
#     accuracy                           0.95      9042
#    macro avg       0.47      0.50      0.49      9042
# weighted avg       0.90      0.95      0.92      9042
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.96      8566
#            1       0.42      0.84      0.56       476
#
#     accuracy                           0.93      9042
#    macro avg       0.71      0.89      0.76      9042
# weighted avg       0.96      0.93      0.94      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8877
#            1       0.00      0.00      0.00       165
#
#     accuracy                           0.98      9042
#    macro avg       0.49      0.50      0.50      9042
# weighted avg       0.96      0.98      0.97      9042
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98      8877
#            1       0.31      0.72      0.43       165
#
#     accuracy                           0.97      9042
#    macro avg       0.65      0.85      0.71      9042
# weighted avg       0.98      0.97      0.97      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      8632
#            1       0.00      0.00      0.00       410
#
#     accuracy                           0.95      9042
#    macro avg       0.48      0.50      0.49      9042
# weighted avg       0.91      0.95      0.93      9042
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98      8632
#            1       0.58      0.87      0.69       410
#
#     accuracy                           0.97      9042
#    macro avg       0.79      0.92      0.84      9042
# weighted avg       0.97      0.97      0.97      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      8713
#            1       0.00      0.00      0.00       329
#
#     accuracy                           0.96      9042
#    macro avg       0.48      0.50      0.49      9042
# weighted avg       0.93      0.96      0.95      9042
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99      8713
#            1       0.57      0.90      0.70       329
#
#     accuracy                           0.97      9042
#    macro avg       0.78      0.94      0.84      9042
# weighted avg       0.98      0.97      0.97      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      8108
#            1       0.00      0.00      0.00       934
#
#     accuracy                           0.90      9042
#    macro avg       0.45      0.50      0.47      9042
# weighted avg       0.80      0.90      0.85      9042
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96      8108
#            1       0.62      0.86      0.72       934
#
#     accuracy                           0.93      9042
#    macro avg       0.80      0.90      0.84      9042
# weighted avg       0.94      0.93      0.93      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      8716
#            1       0.00      0.00      0.00       326
#
#     accuracy                           0.96      9042
#    macro avg       0.48      0.50      0.49      9042
# weighted avg       0.93      0.96      0.95      9042
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97      8716
#            1       0.37      0.83      0.51       326
#
#     accuracy                           0.94      9042
#    macro avg       0.68      0.89      0.74      9042
# weighted avg       0.97      0.94      0.95      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.89      7178
#            1       0.00      0.00      0.00      1864
#
#     accuracy                           0.79      9042
#    macro avg       0.40      0.50      0.44      9042
# weighted avg       0.63      0.79      0.70      9042
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91      7178
#            1       0.64      0.79      0.71      1864
#
#     accuracy                           0.86      9042
#    macro avg       0.79      0.84      0.81      9042
# weighted avg       0.88      0.86      0.87      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8837
#            1       0.00      0.00      0.00       205
#
#     accuracy                           0.98      9042
#    macro avg       0.49      0.50      0.49      9042
# weighted avg       0.96      0.98      0.97      9042
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97      8837
#            1       0.27      0.66      0.38       205
#
#     accuracy                           0.95      9042
#    macro avg       0.63      0.81      0.68      9042
# weighted avg       0.98      0.95      0.96      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      8781
#            1       0.00      0.00      0.00       261
#
#     accuracy                           0.97      9042
#    macro avg       0.49      0.50      0.49      9042
# weighted avg       0.94      0.97      0.96      9042
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98      8781
#            1       0.42      0.87      0.57       261
#
#     accuracy                           0.96      9042
#    macro avg       0.71      0.92      0.77      9042
# weighted avg       0.98      0.96      0.97      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      8091
#            1       0.00      0.00      0.00       951
#
#     accuracy                           0.89      9042
#    macro avg       0.45      0.50      0.47      9042
# weighted avg       0.80      0.89      0.85      9042
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      8091
#            1       0.73      0.87      0.79       951
#
#     accuracy                           0.95      9042
#    macro avg       0.86      0.91      0.88      9042
# weighted avg       0.96      0.95      0.95      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      7736
#            1       0.00      0.00      0.00      1306
#
#     accuracy                           0.86      9042
#    macro avg       0.43      0.50      0.46      9042
# weighted avg       0.73      0.86      0.79      9042
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93      7736
#            1       0.57      0.79      0.67      1306
#
#     accuracy                           0.89      9042
#    macro avg       0.77      0.85      0.80      9042
# weighted avg       0.91      0.89      0.89      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      8563
#            1       0.00      0.00      0.00       479
#
#     accuracy                           0.95      9042
#    macro avg       0.47      0.50      0.49      9042
# weighted avg       0.90      0.95      0.92      9042
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.95      8563
#            1       0.37      0.81      0.51       479
#
#     accuracy                           0.92      9042
#    macro avg       0.68      0.87      0.73      9042
# weighted avg       0.96      0.92      0.93      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      8428
#            1       0.00      0.00      0.00       614
#
#     accuracy                           0.93      9042
#    macro avg       0.47      0.50      0.48      9042
# weighted avg       0.87      0.93      0.90      9042
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.96      8428
#            1       0.51      0.84      0.63       614
#
#     accuracy                           0.93      9042
#    macro avg       0.75      0.89      0.80      9042
# weighted avg       0.96      0.93      0.94      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90      7380
#            1       0.00      0.00      0.00      1662
#
#     accuracy                           0.82      9042
#    macro avg       0.41      0.50      0.45      9042
# weighted avg       0.67      0.82      0.73      9042
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91      7380
#            1       0.59      0.80      0.68      1662
#
#     accuracy                           0.86      9042
#    macro avg       0.77      0.84      0.80      9042
# weighted avg       0.88      0.86      0.87      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      8408
#            1       0.00      0.00      0.00       634
#
#     accuracy                           0.93      9042
#    macro avg       0.46      0.50      0.48      9042
# weighted avg       0.86      0.93      0.90      9042
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95      8408
#            1       0.42      0.79      0.55       634
#
#     accuracy                           0.91      9042
#    macro avg       0.70      0.85      0.75      9042
# weighted avg       0.94      0.91      0.92      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      8674
#            1       0.00      0.00      0.00       368
#
#     accuracy                           0.96      9042
#    macro avg       0.48      0.50      0.49      9042
# weighted avg       0.92      0.96      0.94      9042
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.95      8674
#            1       0.29      0.78      0.42       368
#
#     accuracy                           0.91      9042
#    macro avg       0.64      0.85      0.69      9042
# weighted avg       0.96      0.91      0.93      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      8676
#            1       0.00      0.00      0.00       366
#
#     accuracy                           0.96      9042
#    macro avg       0.48      0.50      0.49      9042
# weighted avg       0.92      0.96      0.94      9042
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97      8676
#            1       0.43      0.83      0.57       366
#
#     accuracy                           0.95      9042
#    macro avg       0.71      0.89      0.77      9042
# weighted avg       0.97      0.95      0.96      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      8201
#            1       0.00      0.00      0.00       841
#
#     accuracy                           0.91      9042
#    macro avg       0.45      0.50      0.48      9042
# weighted avg       0.82      0.91      0.86      9042
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93      8201
#            1       0.42      0.82      0.56       841
#
#     accuracy                           0.88      9042
#    macro avg       0.70      0.85      0.74      9042
# weighted avg       0.93      0.88      0.90      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      8037
#            1       0.00      0.00      0.00      1005
#
#     accuracy                           0.89      9042
#    macro avg       0.44      0.50      0.47      9042
# weighted avg       0.79      0.89      0.84      9042
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.88      0.92      8037
#            1       0.45      0.81      0.58      1005
#
#     accuracy                           0.87      9042
#    macro avg       0.71      0.84      0.75      9042
# weighted avg       0.92      0.87      0.89      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      8597
#            1       0.00      0.00      0.00       445
#
#     accuracy                           0.95      9042
#    macro avg       0.48      0.50      0.49      9042
# weighted avg       0.90      0.95      0.93      9042
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97      8597
#            1       0.51      0.87      0.64       445
#
#     accuracy                           0.95      9042
#    macro avg       0.75      0.92      0.81      9042
# weighted avg       0.97      0.95      0.96      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      8411
#            1       0.00      0.00      0.00       631
#
#     accuracy                           0.93      9042
#    macro avg       0.47      0.50      0.48      9042
# weighted avg       0.87      0.93      0.90      9042
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.96      8411
#            1       0.46      0.85      0.59       631
#
#     accuracy                           0.92      9042
#    macro avg       0.72      0.89      0.77      9042
# weighted avg       0.95      0.92      0.93      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85      6661
#            1       0.00      0.00      0.00      2381
#
#     accuracy                           0.74      9042
#    macro avg       0.37      0.50      0.42      9042
# weighted avg       0.54      0.74      0.62      9042
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.81      0.85      6661
#            1       0.59      0.75      0.66      2381
#
#     accuracy                           0.79      9042
#    macro avg       0.74      0.78      0.75      9042
# weighted avg       0.82      0.79      0.80      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# DUMB predictor
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.87      7016
#            1       0.00      0.00      0.00      2026
#
#     accuracy                           0.78      9042
#    macro avg       0.39      0.50      0.44      9042
# weighted avg       0.60      0.78      0.68      9042
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.83      7016
#            1       0.47      0.69      0.56      2026
#
#     accuracy                           0.76      9042
#    macro avg       0.68      0.73      0.70      9042
# weighted avg       0.80      0.76      0.77      9042
# /home/nozza/bert/lib64/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
pd.set_option("display.max_columns", None)
pd.DataFrame.from_dict(results_dumb)
# Out:
#        B_ldisc  B_wellbeing    B_demo  B_general   B_labor  B_historyeco  \
# prec  0.497843     0.489106  0.476941   0.491761  0.473678      0.490876
# rec   0.500000     0.500000  0.500000   0.500000  0.500000      0.500000
# f1    0.498919     0.494493  0.488198   0.495846  0.486483      0.495396
# acc   0.995687     0.978213  0.953882   0.983521  0.947357      0.981752
#
#       B_health  B_education   B_gamet  B_hhbehaviour  B_develop  B_business  \
# prec  0.477328     0.481807  0.448352       0.481973   0.396925    0.488664
# rec   0.500000     0.500000  0.500000       0.500000   0.500000    0.500000
# f1    0.488401     0.490735  0.472770       0.490821   0.442540    0.494267
# acc   0.954656     0.963614  0.896704       0.963946   0.793851    0.977328
#
#        B_wages  B_naturalr  B_public  B_demandlab   B_trade  B_industrial  \
# prec  0.485567    0.447412  0.427781     0.473512  0.466047      0.408096
# rec   0.500000    0.500000  0.500000     0.500000  0.500000      0.500000
# f1    0.492678    0.472247  0.461080     0.486396  0.482427      0.449397
# acc   0.971135    0.894824  0.855563     0.947025  0.932095      0.816191
#
#       B_intern  B_welfare  B_urbanregional  B_ecohistory  B_lawecon  \
# prec  0.464941   0.479651         0.468757      0.491484   0.482084
# rec   0.500000   0.500000         0.500000      0.500000   0.500000
# f1    0.481834   0.489614         0.483875      0.495706   0.490878
# acc   0.929883   0.959301         0.937514      0.982968   0.964167
#
#       B_collectivedec  B_financial  B_macroconsum  B_macropolicy    B_prod  \
# prec         0.471466     0.435468       0.475614       0.479761  0.453495
# rec          0.500000     0.500000       0.500000       0.500000  0.500000
# f1           0.485314     0.465508       0.487502       0.489672  0.475613
# acc          0.942933     0.870936       0.951228       0.959522  0.906990
#
#          B_inf  B_macromoney  B_macroprices    B_math   B_other
# prec  0.444426      0.475393       0.465107  0.368337  0.387967
# rec   0.500000      0.500000       0.500000  0.500000  0.500000
# f1    0.470578      0.487386       0.481923  0.424186  0.436916
# acc   0.888852      0.950785       0.930215  0.736673  0.775935

# %%
results = pd.DataFrame.from_dict(results)
results
# Out:
#        B_ldisc  B_wellbeing    B_demo  B_general   B_labor  B_historyeco  \
# prec  0.708342     0.665475  0.702937   0.660390  0.705686      0.650298
# rec   0.856808     0.866403  0.888744   0.853065  0.887072      0.845398
# f1    0.762760     0.723883  0.760180   0.717650  0.761409      0.705788
# acc   0.994470     0.961955  0.937956   0.970582  0.930768      0.965052
#
#       B_health  B_education   B_gamet  B_hhbehaviour  B_develop  B_business  \
# prec  0.785757     0.784331  0.798827       0.681532   0.789265    0.629816
# rec   0.919086     0.937166  0.896896       0.890560   0.837728    0.810659
# f1    0.837775     0.842514  0.837784       0.740905   0.808648    0.678050
# acc   0.965273     0.971909  0.929772       0.942712   0.863747    0.951228
#
#        B_wages  B_naturalr  B_public  B_demandlab   B_trade  B_industrial  \
# prec  0.707617    0.857875  0.768326     0.679431  0.748282      0.770121
# rec   0.918788    0.914565  0.846928     0.867400  0.889896      0.837947
# f1    0.773131    0.883326  0.798316     0.731535  0.798621      0.795034
# acc   0.961402    0.952555  0.885092     0.916833  0.934085      0.860650
#
#       B_intern  B_welfare  B_urbanregional  B_ecohistory  B_lawecon  \
# prec  0.700761   0.640046         0.725030      0.631132   0.671766
# rec   0.851653   0.850666         0.869211      0.821686   0.850907
# f1    0.747747   0.688138         0.774507      0.682362   0.724957
# acc   0.908538   0.913183         0.929772      0.963061   0.941716
#
#       B_collectivedec  B_financial  B_macroconsum  B_macropolicy    B_prod  \
# prec         0.709897     0.798321       0.653193       0.713738  0.701339
# rec          0.870171     0.878691       0.836393       0.892537  0.852855
# f1           0.761717     0.830675       0.700121       0.772020  0.744153
# acc          0.928556     0.913294       0.909754       0.949458  0.879230
#
#          B_inf  B_macromoney  B_macroprices    B_math   B_other
# prec  0.713472      0.750533       0.722240  0.742686  0.683390
# rec   0.843510      0.915152       0.885390  0.778882  0.732667
# f1    0.752229      0.808391       0.774191  0.754821  0.695501
# acc   0.870383      0.952112       0.919044  0.794293  0.756470

# %%
ins_df = pd.DataFrame(columns = target_fields)
for t in target_fields:
    ins_df[t] = insight[t]['feature'].values
ins_df
# Out:
#                       B_ldisc   B_wellbeing          B_demo     B_general  \
# 0                      gender          well          gender        social
# 1                    students        social        children       network
# 2                        tend   contributes           women     economics
# 3                    networks        living         childre   individuals
# 4                       women         socio         parents         prova
# 5             negativo impact    indicators            life      building
# 6                      scheme      measured      population      samplere
# 7                       field     migration          female          life
# 8                 application     countries     demographic      cultural
# 9                     explain    households      endogenous         lower
# 10                  conducted   expenditura      retirement        linear
# 11                    perform        single     controlling      location
# 12                  selection         micro     endogeneity  convergencia
# 13                 experience      proposes          health         trust
# 14                        gap         taxes           lower          type
# 15                   negativo        health            care     dimension
# 16                  involving          life     endogenouso       paperre
# 17             municipalities   persistence  opportunitieso       measure
# 18                      italy   controlling     association  intervention
# 19                measurement   individuals         related       exposed
# 20                    premium          need         effects          form
# 21                  considers         apply             age        others
# 22  statistically significant        trends          strong         goods
# 23                   thendere  longitudinal          family        search
# 24                      using      advanced             old       defined
# 25                      group         index        aversion     functions
# 26                      offer         order          robust      provided
# 27                competitivo         years      hypothesis          deal
# 28                  treatment    retirement   significantly          self
# 29                    workers    components       recession        causal
#
#           B_labor     B_historyeco        B_health    B_education  \
# 0         workers        economics          health      education
# 1          worker           theory              00         school
# 2    unemployment          variety            care       students
# 3           union       considered     consumption     university
# 4            wage     evolutionary       treatment    educational
# 5   labour market          complex          female       research
# 6             job           system      endogenous     evaluation
# 7      employment      particulare          likely    application
# 8       migration            great         quality          south
# 9        mobility         problems      population       academic
# 10     bargaining  economic growth        national  human capital
# 11         reform          smaller     individuals       focusing
# 12      recession          emerges     association       children
# 13         labour             sets      government       earnings
# 14      presencia            legal        reducing  labour market
# 15        working       investment           italy        article
# 16         shocks      preferences             age          would
# 17     variations          derived           early         report
# 18    paper shows           effort            show   accumulation
# 19          labor        presented         control         labour
# 20       provides           issues      understand        confirm
# 21      countries     technologies        response     literatura
# 22    consequence             view     investigare       suggests
# 23       variable        keynesian           novel          human
# 24      relations            shown  socio economic        premium
# 25         robust             0000          higher         skills
# 26      aggregare         consider        capitare       southern
# 27  characterized       regulation       pollution       learning
# 28   transmission        influence           study       positivo
# 29        studies          problem          across           many
#
#          B_gamet B_hhbehaviour             B_develop     B_business  \
# 0           game    households                growth      employees
# 1   experimental   consumption            innovation       concerns
# 2   experimentre     consumers                patent       creation
# 3       subjects   preferences           development         effort
# 4          games        demand             knowledge         worker
# 5    experiments     household            innovativa      corporare
# 6        perfect        saving          technologies        variety
# 7   evolutionary        single         technological      knowledge
# 8   participants         event            technology       taxation
# 9    cooperation      consumer         developmentre        workers
# 10    laboratory          care               economy     difference
# 11          nash       childre  developing countries      condition
# 12    experiment   individuals              research        working
# 13       choices     transport    empirical evidence         profit
# 14        whicho        change             diffusion    performance
# 15      matching     investors             countries      companies
# 16         field        reveal               product  organizations
# 17     strategic     condition            spillovers        becausa
# 18     treatment       utility              capitare          order
# 19       players   probability          productivity       strongly
# 20   preferences        matter             migration             00
# 21      behavior       privato                   sub         family
# 22    behavioral      findings          convergencia          found
# 23   willingness        survey               capital       industry
# 24       ability       product         institutional            way
# 25         among    experiment                  path            use
# 26        agents        family             community    opportunity
# 27        stable       measura            activities     monitoring
# 28          rule         taxes            indicators         driver
# 29      feedback         italy               support         theory
#
#          B_wages      B_naturalr        B_public    B_demandlab  \
# 0           wage   environmental             tax     retirement
# 1          wages          energy          public         supply
# 2       earnings         climata          fiscal     employment
# 3      employees             oil  redistribution          labor
# 4            pay        resource      government         labour
# 5         labour       pollution        benefits  human capital
# 6   labor market           green           taxes           work
# 7        workers       emissions       provision          human
# 8       students          carbon        security       children
# 9        skilled     sustainable            debt        article
# 10          isre      management         concern          wages
# 11        effort          prices        taxation         school
# 12           pro         natural      asymmetric            job
# 13    employment        emission   contributions           time
# 14    incentives      production          design       students
# 15          part         impacts             pre          skill
# 16        action          futuro     governments         wealth
# 17        worker       improving  municipalities       employed
# 18   differences       reduction         society           rolo
# 19     different       provinces         parents       earnings
# 20  results show        indicare        spending         skills
# 21     incentivo          supply         confirm       european
# 22         adopt         sources      compliance          least
# 23    explaining      associated      techniques        working
# 24           ltd           field      corruption        workers
# 25    suggesting  implementation        measures           home
# 26        better        capacity       elections      employees
# 27   independent        products        policies        general
# 28   sensitivity        taxation      endogenous           rich
# 29          paid        security         project        dataset
#
#             B_trade B_industrial         B_intern      B_welfare  \
# 0            export        firms          foreign  externalities
# 1             trade      duopoly        migration     individual
# 2       integration     industry    international     inequality
# 3     international   regulatory          country        welfare
# 4           country         firm       exchangere        society
# 5           tradere        entry         domestic         income
# 6           exports    consumers         linkages         social
# 7            global      pricing           direct    individuals
# 8           regions   industrial  exchangere rare  organizations
# 9             union     business         stronger          prova
# 10         domestic      service      flexibility         others
# 11     productivity      product         currency       mobility
# 12          foreign     vertical            legal      comparing
# 13  exchangere rare  competition         possible  environmental
# 14             euro      cournot              way          index
# 15        countries    corporare   opportunitieso    cooperation
# 16           inputs     projects            flows           well
# 17      enterprises    ownership         external           make
# 18       decreasing   incentives           crisis         though
# 19           member      italian           global          valuo
# 20     accumulation       market          skilled        spatial
# 21       industries       sapere             bank      following
# 22            takee       profit          driving          human
# 23          nominal   regulation          factors            act
# 24            china      profits        countries      mechanism
# 25            flows         post          sectore            one
# 26         contrast     focusing      investments   participants
# 27      constrained         need              gdp        beliefs
# 28         external     generare            shown    instruments
# 29       exchangere     consumer        investors    willingness
#
#       B_urbanregional   B_ecohistory      B_lawecon B_collectivedec  \
# 0            regional     historical     corruption       political
# 1             regions            gdp          legal      corruption
# 2           transport         period            law       elections
# 3             spatial       business    enforcement       electoral
# 4               local          world         system     enforcement
# 5            location         growth       supports        citizens
# 6      specifications         united           lead          groups
# 7               areas       capitare       property          social
# 8                area     population       contract         outcome
# 9                  eu         cycles         effect      government
# 10              multo    integration      reduction          public
# 11  empirical results   relationship       policies       decisions
# 12            impacts            pre      efficient     governments
# 13          provinces      threshold          italy       transport
# 14             region          0000s         points      hypothesis
# 15            largest  united states  organizations        distance
# 16           sectoral         school         states          makers
# 17             higher      temporary       increase       condition
# 18         regulatory          years           post  redistribution
# 19              socio        natural     protection           leads
# 20            results     hypothesis          aimed          single
# 21              level         better      influence          action
# 22          different         shaped           lack           chooe
# 23             number           0000          study         provido
# 24           mobility       currency           paid  municipalities
# 25            changes          great       required            rule
# 26               dato  manufacturing            top      protection
# 27              still        ability       proposes             low
# 28         spillovers         events       analyzed    consequences
# 29           variable      intensity       business          people
#
#    B_financial        B_macroconsum  B_macropolicy           B_prod  \
# 0      banking               saving         fiscal            firms
# 1    financial         unemployment          labor             pore
# 2        banks            inflation         policy    manufacturing
# 3         bank          consumption       spending             firm
# 4    portfolio            aggregata  fiscal policy            value
# 5         risk                  gdp  macroeconomic    organizations
# 6        asset           investment            tax         frontier
# 7       credit          sensitivity          green          cournot
# 8        stock                 rola           real           prices
# 9   volatility  general equilibrium        economy     institutions
# 10      wealth             function            job      authorities
# 11     markets               wealth          rules     productivity
# 12      market              workers     government      competition
# 13      equity           employment  findings show            first
# 14   corporare         uncertaintyo       taxation          duopoly
# 15     returns                labor           debt  competitiveness
# 16        debt           households    investments        temporary
# 17    leverage                first       economic             cost
# 18     trading            aggregare             eu       efficiency
# 19      option                model   expectations            banks
# 20   companies        labour market            age         quantity
# 21      return               sector         shocks            north
# 22   ownership             standard          taxes             data
# 23      toward          furthermore          larga            price
# 24       funds             generare        looking         property
# 25   investors              economy        provide      theoretical
# 26    variance               income          short              two
# 27    systemic           retirement          inter          pricing
# 28    analyzes                 poor         activo       production
# 29     sharing               search      existence            stage
#
#              B_inf     B_macromoney   B_macroprices             B_math  \
# 0      information        inflation    fluctuations        agent based
# 1          network         monetary       inflation           dynamics
# 2          beliefs          nominal          cycles         simulation
# 3         learning           policy         economy            spatial
# 4     expectations            banks       recession         estimation
# 5             risk            asset           cycle                var
# 6     uncertaintyo          central          shocks             system
# 7          project            money          output       results show
# 8         decision  monetary policy           based        investigate
# 9           signal     uncertaintyo        monetary        statistical
# 10         ability         interest  business cycle           variance
# 11        expected            shock     simulations          nonlinear
# 12        aversion        liquidity   macroeconomic           estimare
# 13     probability             euro         periods              tests
# 14          wealth             rule        leverage          variables
# 15       incentivo            reale       aggregata            testing
# 16        networks        keynesian         leading        conditional
# 17          agents           credit        activity           problems
# 18     equilibrium     expectations       keynesian             debare
# 19       connected           crisis           south          modelling
# 20          making         response          steady           forecast
# 21       selection         decrease      phenomenon              panel
# 22        forecast            rules           model          selection
# 23        subjects              net        equation  agent based model
# 24            loss          implies            pore               data
# 25        critical        following           space            article
# 26   communication             rare            area             energy
# 27  implementation     contribution    characterize              stock
# 28       decisions       transition      endogenous             vector
# 29        standard              var           great               time
#
#               B_other
# 0            cultural
# 1              social
# 2          inequality
# 3                well
# 4             members
# 5   financial markets
# 6         willingness
# 7              static
# 8               money
# 9              people
# 10              yield
# 11             others
# 12            looking
# 13               self
# 14               life
# 15           measures
# 16              socio
# 17         historical
# 18        constrained
# 19              total
# 20            whereas
# 21            general
# 22        opportunity
# 23          generally
# 24            beliefs
# 25           bayesian
# 26           approach
# 27          political
# 28         allocation
# 29         concerning

# %%
result_no_stopwords = pd.DataFrame.from_dict(results)

# %%
print('MEAN F1: ', np.round(results.loc['f1'].mean(),3))
print('STOPWORDS MEAN F1: ', np.round(result_no_stopwords.loc['f1'].mean(),3))
# Out:
# MEAN F1:  0.793
# STOPWORDS MEAN F1:  0.789

# %%
#pd.DataFrame.from_dict(insight)

# %%
#pd.concat([insight[t]['feature'][0:10] for t in target_fields],axis=1,ignore_index=False)

# %%
pd.DataFrame.from_dict(results)kf = KFold(n_splits=5)
    
if not(selector is None):
    X_sel = selector.fit_transform(X, y)
else:
    X_sel = X_train

most_frequent = DummyClassifier(strategy='most_frequent')
most_frequent.fit(X_sel, y)
# get the performance on the development set
dumb_predictions = most_frequent.predict(X_sel)
print("DUMB predictor")
#print(classification_report(y, dumb_predictions))

print("Multi-output Random Forest")
forest = RandomForestClassifier(random_state=1)
multi_target_forest = MultiOutputClassifier(forest, n_jobs=-1)

for train_index, test_index in kf.split(X_train):
    print("SPLIT")
    X_train_cv, X_test_cv = X_train[train_index], X_train[test_index]
    y_train_cv, y_test_cv = y[train_index], y[test_index]

    y_preds = multi_target_forest.fit(X_train_cv, y_train_cv).predict(X_test_cv)

    print(classification_report(y_test_cv, preds))

# %%
kf = KFold(n_splits=5)

print("Multi-output LR")
classifier = LogisticRegression(class_weight='balanced',
                                        solver='saga',
                                        penalty='elasticnet', 
                                        l1_ratio=0.5, 
                                        n_jobs=-1)
multi_target_forest = MultiOutputClassifier(classifier, n_jobs=-1)

for train_index, test_index in kf.split(X_train):
    print("SPLIT")
    X_train_cv, X_test_cv = X_train[train_index], X_train[test_index]
    y_train_cv, y_test_cv = y[train_index], y[test_index]

    y_preds = multi_target_forest.fit(X_train_cv, y_train_cv).predict(X_test_cv)

    print(classification_report(y_test_cv, preds))
# Out:
# Multi-output LR
# SPLIT

# %%
train['micro'].value_counts()
# Out:
# 0.0    5791
# 1.0    3223
# Name: micro, dtype: int64

# %%
I[I['class'] == 'Kavanaugh']#.to_excel('data/indicators_judges.xlsx', index=None)
# Out:
#                           feature      class  coefficient
# 3869                court declare  Kavanaugh     4.754086
# 4352                dangerousness  Kavanaugh     4.546067
# 2323              case reasonable  Kavanaugh     3.775475
# 2322                  case reason  Kavanaugh     3.003807
# 3547               contrast court  Kavanaugh     2.716101
# 4250             criminal offense  Kavanaugh     2.685944
# 4757                    deterrent  Kavanaugh     2.595863
# 3865               court decision  Kavanaugh     2.508349
# 67                        00 stat  Kavanaugh     2.436689
# 3619                    corporate  Kavanaugh     2.358015
# 1103                 amici curiae  Kavanaugh     2.299347
# 4257  criminal prosecution accuse  Kavanaugh     2.291191
# 1087     american bar association  Kavanaugh     2.258843
# 1086                 american bar  Kavanaugh     2.251219
# 4756                   deterrence  Kavanaugh     2.248808
# 5371                   effect law  Kavanaugh     2.222017
# 5121                      drafter  Kavanaugh     2.198539
# 5918          express pre emption  Kavanaugh     2.106628
# 4203                     creation  Kavanaugh     2.044406
# 1654                       atkins  Kavanaugh     2.030780
# 5383                effectiveness  Kavanaugh     2.009821
# 2171           capital sentencing  Kavanaugh     2.001668
# 756                   adhere view  Kavanaugh     1.956165
# 4547              defendant prior  Kavanaugh     1.897845
# 587                act constitute  Kavanaugh     1.881834
# 5108               doubt congress  Kavanaugh     1.869448
# 3085                   competitor  Kavanaugh     1.862801
# 233                    0d app pet  Kavanaugh     1.852852
# 3511                   contingent  Kavanaugh     1.759671
# 4308                 curiae brief  Kavanaugh     1.741152

# %%
y = df.TEXT_TYPE

X_sel = evaluate(X, y, selector)
insights(X_sel, y, selector)
# Out:
# /Users/dirkhovy/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dirkhovy/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dirkhovy/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dirkhovy/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
#               precision    recall  f1-score   support
#
#           NA       0.00      0.00      0.00         1
#   concurring       0.00      0.00      0.00       901
#   dissenting       0.00      0.00      0.00      1192
#         main       0.43      1.00      0.60      1598
#
#     accuracy                           0.43      3692
#    macro avg       0.11      0.25      0.15      3692
# weighted avg       0.19      0.43      0.26      3692
#
#               precision    recall  f1-score   support
#
#           NA       0.00      0.00      0.00         1
#   concurring       0.79      0.82      0.81       901
#   dissenting       0.87      0.82      0.84      1192
#         main       0.98      0.99      0.98      1598
#
#     accuracy                           0.90      3692
#    macro avg       0.66      0.66      0.66      3692
# weighted avg       0.90      0.90      0.89      3692
# /Users/dirkhovy/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
#                            feature       class  coefficient
# 5539                       eng rep        main     5.420973
# 1875                         bench        main     5.310017
# 1874                        belong        main     5.303003
# 2060                         brown        main     4.423952
# 3463      constitutionally protect        main     4.176779
# 3462  constitutionally permissible        main     4.166164
# 2891              co united states        main     3.871987
# 2059                      brothers        main     3.584215
# 1115                            an        main     3.297807
# 2702                   claim allow        main     3.000620
# 546                   accuse enjoy  dissenting     7.989889
# 4859                disagree court  dissenting     6.724199
# 3663                   council inc  dissenting     5.390265
# 3476                      construe  dissenting     3.011875
# 5658                      err hold  dissenting     2.760681
# 3364         consider circumstance  dissenting     2.635571
# 3479                  consultation  dissenting     2.614623
# 3466                        constr  dissenting     2.450395
# 559                        acquire  dissenting     2.196875
# 446                      0d vacate  dissenting     1.992283
# 3355                   consequence  concurring     9.377992
# 3473                  constructive  concurring     6.806480
# 3363                 consider case  concurring     4.702481
# 3470                     construct  concurring     4.361390
# 464                        abandon  concurring     4.232391
# 5977           fact light evidence  concurring     3.366565
# 4350                        danger  concurring     2.570428
# 3383                  considerable  concurring     2.419926
# 3397                  consolidated  concurring     2.043356
# 3468                     constrain  concurring     1.993245
# 826            adverse consequence          NA    18.779549
# 990                    allow claim          NA    17.911925
# 2628               circumstance id          NA    15.030595
# 3780            court appeals view          NA    14.991945
# 5578                   enter order          NA    14.524245
# 5239                 ed 0d example          NA    14.374652
# 5581           enter united states          NA    12.574712
# 3292                congress leave          NA    11.833842
# 845                        affairs          NA    11.060588
# 5579                    enter plea          NA    10.667654

# %%
y = df.CAT1

X_sel = evaluate(X, y, selector)
insights(X_sel, y, selector)
# Out:
# /Users/dirkhovy/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dirkhovy/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dirkhovy/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dirkhovy/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn
# ESTATE PLANNING AND PROBATE       0.00      0.00      0.00         2
#                  FAMILY LAW       0.56      0.62      0.59        53
#         FINANCE AND BANKING       0.44      0.64      0.52        11
#                        GLBT       0.38      0.46      0.41        13
#                  GOVERNMENT       0.75      0.49      0.59       306
#        GOVERNMENT CONTRACTS       0.33      0.67      0.44        15
#                  GOVERNMNET       0.00      0.00      0.00         1
#                      HEALTH       0.32      0.47      0.38        38
#                 IMMIGRATION       0.86      0.87      0.87       115
#                   INSURANCE       0.58      0.88      0.70         8
#       INTELLECTUAL PROPERTY       0.40      0.12      0.18        17
#           INTERNATIONAL LAW       0.38      0.70      0.50        44
#     JUDICIAL ADMINISTRATION       0.43      0.76      0.55        17
#        LABOR AND EMPLOYMENT       0.83      0.67      0.74       289
#              LEGAL SERVICES       0.24      0.44      0.31         9
#                  LITIGATION       0.60      0.45      0.51       186
#                MARITIME LAW       0.57      0.94      0.71        18
#                MILITARY LAW       0.32      0.75      0.44        16
#            NATIVE AMERICANS       0.68      0.94      0.79        67
#                     PATENTS       0.90      0.94      0.92        69
#          PRODUCTS LIABILITY       0.46      0.76      0.57        29
#               REAL PROPERTY       0.48      0.60      0.53        53
#       SECURITIES REGULATION       0.79      0.81      0.80        62
#             SOCIAL SECUIRTY       0.00      0.00      0.00         1
#             SOCIAL SECURITY       0.59      0.71      0.65        28
#                    TAXATION       0.72      0.88      0.79        82
#                       TORTS       0.34      0.61      0.44        18
#                  TRADEMARKS       0.73      0.84      0.78        19
#              TRANSPORTATION       0.37      0.46      0.41        37
#                    VETERANS       1.00      0.67      0.80         3
#
#                    accuracy                           0.72      3692
#                   macro avg       0.52      0.61      0.54      3692
#                weighted avg       0.74      0.72      0.72      3692
#               feature                    class  coefficient
# 5804           excess                 VETERANS     2.671189
# 5805        excessive                 VETERANS     2.560751
# 5777         exacting                 VETERANS     2.063851
# 4857     disadvantage                 VETERANS     1.870035
# 2169   capital murder                 VETERANS     1.459619
# ...               ...                      ...          ...
# 256       0d citation  ADMINISTRATIVE PRACTICE     1.627738
# 263           0d colo  ADMINISTRATIVE PRACTICE     1.546033
# 4290               ct  ADMINISTRATIVE PRACTICE     1.525705
# 262   0d collect case  ADMINISTRATIVE PRACTICE     1.450465
# 4954    dispute party  ADMINISTRATIVE PRACTICE     1.393609
#
# [430 rows x 3 columns]

# %%
y = df.CAT2

X_sel = evaluate(X, y, selector)
insights(X_sel, y, selector)
# Out:
# /Users/dirkhovy/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dirkhovy/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dirkhovy/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dirkhovy/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
#                                 precision    recall  f1-score   support
#
#                                      0.00      0.00      0.00         5
#                       Abortion       0.00      0.00      0.00        26
#                     Abstention       0.00      0.00      0.00         3
#               Additions To Tax       0.00      0.00      0.00         1
#        Administrative Practice       0.00      0.00      0.00         3
#                      Admission       0.00      0.00      0.00        13
#                       Adoption       0.00      0.00      0.00         1
#                    Advertising       0.00      0.00      0.00         6
#                    Agriculture       0.00      0.00      0.00         1
#                         Aliens       0.00      0.00      0.00         2
#                    Settlements       0.40      0.67      0.50         6
#                  Sex Offenders       0.88      0.21      0.33        34
#                   Sex Offenses       0.17      0.75      0.27         4
#                       Shipping       0.00      0.00      0.00         1
#                       Software       1.00      1.00      1.00         3
#                    Solid Waste       0.40      1.00      0.57         4
#             Sovereign Immunity       0.67      0.53      0.59        15
#           Sovereign Sovereigns       0.14      1.00      0.25         2
#                   Speedy Trial       0.91      0.83      0.87        12
#                            Ssi       0.00      0.00      0.00         2
#                   State Action       0.00      0.00      0.00         1
#                         States       1.00      0.07      0.13        28
#                           Stay       0.00      0.00      0.00         1
#             Subsidized Housing       0.00      0.00      0.00         1
#                       Taxation       0.50      0.86      0.63         7
#                          Taxes       0.33      1.00      0.50         3
#             Telecommunications       0.67      0.07      0.12        30
#                    Territories       0.50      1.00      0.67         5
#       Textbooks And Curriculum       1.00      1.00      1.00         2
#                         Timber       0.11      1.00      0.20         3
#                        Tobacco       0.40      1.00      0.57         2
#                    Tort Claims       0.71      0.45      0.56        11
#                        Torture       0.12      0.50      0.20         2
#                    Trade Dress       0.40      1.00      0.57         2
#                   Traffic Stop       0.00      0.00      0.00         1
#                 Transportation       0.00      0.00      0.00         1
#         Transportation Workers       0.67      0.55      0.60        11
#       Treaties And Conventions       0.21      0.60      0.32         5
#                       Trespass       0.50      0.80      0.62         5
#                          Trial       0.22      1.00      0.36         2
#               Tuition And Fees       0.06      0.25      0.09         4
#         Unfair Labor Practices       0.75      1.00      0.86         3
#                          Union       0.29      1.00      0.44         2
#                         Unions       0.75      0.38      0.50         8
#                  United States       1.00      0.07      0.13        28
#                Useful Articles       1.00      1.00      1.00         3
#                          Usury       0.12      1.00      0.22         2
#                       Vaccines       0.60      0.75      0.67         4
#                          Venue       0.25      0.50      0.33         2
#            Vertical Restraints       0.22      1.00      0.36         2
#            Victim Compensation       0.00      0.00      0.00         1
#                          Visas       0.80      0.29      0.42        14
#                     Visitation       0.50      1.00      0.67         6
#                          Wages       0.00      0.00      0.00         1
#                       Warnings       0.10      0.17      0.12         6
#                          Water       0.00      0.00      0.00        10
#                Water And Sewer       0.00      0.00      0.00         1
#                   Water Rights       0.33      1.00      0.50         5
#                        Weapons       1.00      0.09      0.17        32
#                 Whistleblowing       0.45      1.00      0.62         5
#          Workers’ Compensation       0.67      0.80      0.73         5
#                          Writs       0.67      0.57      0.62         7
#            Zoning And Planning       1.00      0.75      0.86         4
#
#                       accuracy                           0.41      3692
#                      macro avg       0.42      0.60      0.41      3692
#                   weighted avg       0.60      0.41      0.41      3692
#                     feature                class  coefficient
# 3356      consequence court  Zoning And Planning     1.436060
# 5365                eeoc ed  Zoning And Planning     1.039526
# 5974         fact intensive  Zoning And Planning     0.718291
# 3557            control law  Zoning And Planning     0.699847
# 229           0d alteration  Zoning And Planning     0.671328
# ...                     ...                  ...          ...
# 1122          analysis case                          0.675761
# 776              admin news                          0.646892
# 250           0d case court                          0.607528
# 5482    employment practice                          0.549907
# 1889  better environment ed                          0.506769
#
# [2808 rows x 3 columns]

# %%
len(df.CAT2.unique())
# Out:
# 332
